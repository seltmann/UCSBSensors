# %%
import arable
from   arable.client     import ArableClient 
a = ArableClient()
from   sensor_includes   import email, password_ccber, tenant_ccber

a.connect(email = email, password = password_ccber, tenant = tenant_ccber)

from   datetime          import timedelta
from   datetime          import datetime


import pandas            as     pd

dt = datetime.now()

from   io                import StringIO

from arable_data_dict import Hourly_Data_Columns, Daily_Data_Columns, Soil_Data_Columns, Calibrated_Data_Columns

Soil_Data_Columns = {
    "device"          :"Device ID",
    "time"            :"Time stamp",
    "sdi12_value_0"   :"5TE raw VWC (dielectric permittivity)",
    "sdi12_value_1"   :"5TE Bulk EC (dS/m)",
    "sdi12_value_2"   :"5TE Temp (C)",
    "analog"          :"EC-5 Sensor VWC (%)"
}

# Datetime object to string with format "%Y-%m-%dT%H:%M:%SZ"
def dt_to_ymd_hms(x):
    return x.strftime("%Y-%m-%dT%H:%M:%SZ")
# Append string with format "%Y-%m-%dT%H:%M:%SZ" to list
def append_ymd_hms(a, b):
    a.append(dt_to_ymd_hms(b))
# Reverses dt_to_ymd_hms
def ymd_hms_to_dt(x):
    try:
        return datetime.strptime(x, "%Y-%m-%dT%H:%M:%SZ")
    except:
        return datetime.strptime(x, "%Y-%m-%d %H:%M:%S")
    

# Datetime object to string with format "%Y-%m-%d"
def dt_to_ymd(x):
    return x.strftime("%Y-%m-%d")
# Reverse dt_to_ymd
def ymd_to_dt(x):
    return datetime.strptime(x, "%Y-%m-%d")

# Datetime object to string with format "%Y-%m"
def dt_to_ym(x):
    return x.strftime("%Y-%m")
# Append string with format "%Y-%m" to list
def append_ym(a, b):
    try:
        a.append(dt_to_ym(b))
    except:
        a.append(dt_to_ym(ym_to_dt(b)))
# Reverse dt_to_ym
def ym_to_dt(x):
    return datetime.strptime(x, "%Y-%m")

# Append string to list
def append_string(a, b):
    a.append(str(b)[:19])
    
# Append temporary lists to list
def append_temp_list(temp_list, main_list):
    main_list.append(temp_list)

def arable_query(s, b, c, d, e, f, g):
    df = a.query( select = str(s),
                  format = str(b),
                 devices = c,
                 measure = str(d),
                   order = str(e),
                     end = f,
                   start = g,
                   limit = 100000000)
    df = StringIO(df)
    df = pd.read_csv(df, sep=',', error_bad_lines=False)
    return df

start_current_month = ym_to_dt(dt_to_ym(dt)).replace(day=1)
print(start_current_month)
print(dt_to_ym(start_current_month))

today = dt
# Out:
# 2020-04-01 00:00:00
# 2020-04

# %%
device_created = pd.read_csv(str('Sensor-Info_' + str(dt_to_ymd(dt)) + '.txt'), sep = ",")['Date Created'].values.tolist() 
# Monthly
m_start    = []
m_start_fn = []
m_end      = []
m_end_fn   = []

# Yearly
y_start    = []
y_start_fn = []
y_end      = []
y_end_fn   = []

# All Time
astart     = []
start_fn   = []
end        = []
end_fn     = []

for j in range(len(device_created)):
    ms  = []
    msf = []
    me  = []
    mef = []
    
    ys  = []
    ysf = []
    ye  = []
    yef = []
    
    s   = []
    sf  = []
    e   = []
    ef  = []
    
    def new_month(new_m):
        append_ymd_hms(ms, new_m)
        append_string(me, new_m)
        append_ym(msf, new_m)  
        append_ym(mef, new_m)
        
    def new_year(new_y):
        append_ymd_hms(ys, new_y)
        append_string(ye, new_y)
        append_ym(ysf, new_y)
        append_ym(yef, new_y)
    
    device_created_ymd = (device_created[j])[:10]
    start              = ymd_to_dt(device_created_ymd)
    append_string(ms, start)
    append_string(ys, start)
    append_string(s, start)
    append_ym(msf, start)
    append_ym(ysf, start)
    append_ym(sf, start)
    
    start  = start.replace(day=1)
    
    if start.year == dt.year:
        for i in range(start.month+1, dt.month+1):
            new_month(start.replace(month=i))
    
    elif start.year != dt.year: 
        for i in range(dt.year-start.year):
            for j in range(start.month+1, 13): 
                new_month(start.replace(month=j))
        for i in range(start.year+1, dt.year+1):
            newyr = start.replace(year=i, month=1)
            new_year(newyr)
            for j in range(1, dt.month+1):
                new_month(newyr.replace(month=j))
    
    append_string(me, dt)
    append_string(ye, dt)
    append_string(e, dt)
    append_ym(mef, dt)
    append_ym(yef, dt)
    append_ym(ef, dt)
    
    append_temp_list(ms, m_start)
    append_temp_list(me, m_end)
    append_temp_list(msf, m_start_fn)
    append_temp_list(mef, m_end_fn)
    
    append_temp_list(ys, y_start)
    append_temp_list(ye, y_end)
    append_temp_list(ysf, y_start_fn)
    append_temp_list(yef, y_end_fn)
    
    append_temp_list(s, astart)
    append_temp_list(e, end)
    append_temp_list(sf, start_fn)
    append_temp_list(ef, end_fn)
    
print(m_start)
print(m_end)
# Out:
# [['2019-02-05 00:00:00', '2019-03-01T00:00:00Z', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-02-05 00:00:00', '2019-03-01T00:00:00Z', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-03-18 00:00:00', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-02-06 00:00:00', '2019-03-01T00:00:00Z', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-02-05 00:00:00', '2019-03-01T00:00:00Z', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-03-12 00:00:00', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-03-12 00:00:00', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-03-20 00:00:00', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-03-12 00:00:00', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-03-18 00:00:00', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-03-19 00:00:00', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '2019-11-01T00:00:00Z', '2019-12-01T00:00:00Z', '2020-01-01T00:00:00Z', '2020-02-01T00:00:00Z', '2020-03-01T00:00:00Z', '2020-04-01T00:00:00Z'], ['2019-03-14 00:00:00', '2019-04-01T00:00:00Z', '2019-05-01T00:00:00Z', '2019-06-01T00:00:00Z', '2019-07-01T00:00:00Z', '2019-08-01T00:00:00Z', '2019-09-01T00:00:00Z', '2019-10-01T00:00:00Z', '201 ...
# [['2019-03-01 00:00:00', '2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-03-01 00:00:00', '2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-03-01 00:00:00', '2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-03-01 00:00:00', '2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15'], ['2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00', '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00', '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00', '2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00', '2020-04-08 17:26:15']]

# %%
import os
#dirpath = 'C:/Users/ccber-arables/Box/'
dirpath = 'C:/Users/15303/Documents/'

def write_csv_file(sta, end, data_type, data_type_fn, folder, cm, m, remove, dev, loc, site): 
    logfile = 'Log_' + str(dt_to_ymd(today)) + '.txt'
    devicee = "['" + str(dev) + "']"
    fn = str(folder) + str(loc) + '_' + str(cm) + '_' + str(data_type_fn) + '.csv'
    print(fn)
    try:
        df = a.query(select = 'all', 
                     format = 'csv', 
                     devices = devicee, 
                     measure = str(data_type), 
                     order = "time", 
                     end = end, 
                     start = sta, 
                     limit = 100000000)
        
        df = StringIO(df)
        df = pd.read_csv(df, sep=',', error_bad_lines=False)
        while data_type_fn == "Soil":
            raw_VWC = df['sdi12_value_0'].to_list()
            cal_VWC = []
            for i in range(len(raw_VWC)):
                x = float(raw_VWC[i])
                cal_VWC.append(float(4.3*10**(-6)*x**(3) - 5.5*10**(-4)*x**(2) + 2.92*10**(-2)*x - 5.3*10**(-2)))
            df = df.dropna(axis='columns', thresh=2)#how='all')
            tm = df['time'].to_list()
            date_stamp = []
            time_stamp = []
            for i in range(len(tm)):
                date_stamp.append(str(tm[i])[:10])
                time_stamp.append(str(tm[i])[11:][:8])
            df.insert(1, 'Time', time_stamp)
            df.insert(1, 'Date', date_stamp) 
            df.insert(1, 'Habitat', loc)
            df.insert(1, 'Site', site)
            for i in remove:
                print("Remove " + i)
                try:                
                    df = df.drop(i, axis='columns')
                except:
                    pass
            df = df.rename(mapper=m, axis='columns')
            df.insert(6, '5TE Calibrated VWC (m^3/m^3)', cal_VWC)
            df.to_csv(fn, sep = ",")
            print('Successfully wrote ' + fn)
            open(logfile, 'a+').write('Successfully wrote ' + fn + '\n')
        else:
            df = df.dropna(axis='columns', thresh=2)#how='all')
            tm = df['time'].to_list()
            date_stamp = []
            time_stamp = []
            for i in range(len(tm)):
                date_stamp.append(str(tm[i])[:10])
                time_stamp.append(str(tm[i])[11:][:8])
            df.insert(1, 'Time', time_stamp)
            df.insert(1, 'Date', date_stamp)
            df.insert(1, 'Habitat', loc)
            df.insert(1, 'Site', site)
            for i in remove:
                print("Remove " + i)
                df = df.drop(i, axis='columns')
            df = df.rename(mapper=m, axis='columns')
            df.to_csv(fn, sep = ",")
            print('Successfully wrote ' + fn)
            open(logfile, 'a+').write('Successfully wrote ' + fn + '\n')
    except:
        open(logfile, 'a+').write('Failure writing ' + fn + '\n')
        #pass

# %%
#----Site
#--------Habitat
#---------------Year
#-------------------Daily
#-------------------Hourly
#-------------------Soil
   
Sensor_ID            = ['A000229','A000318','A000369','A000465','A000466','A000502','A000507','A000513','A000522','A000536','A000546','A000563']

Site                 = ['Campus_Lagoon','Campus_Lagoon','North_Campus_Open_Space','Campus_Lagoon','North_Campus_Open_Space','North_Campus_Open_Space','Nipomo_Lupine_Project','Nipomo_Lupine_Project','Nipomo_Lupine_Project','Campus_Lagoon','North_Campus_Open_Space','North_Campus_Open_Space']
Habitat              = ['Annual_Grass','Coastal_Sage_Scrub','Ventura_Marsh_Milk-Vetch','Campus_Point_Iceplant','Salt_Marsh','North_Slope_Oaks','Black_Lake_Gentle_South','Black_Lake_North_Facing','Philips_66','2016_Burn_Plot','2017_Stipa_Drillseed','Stipa_Loam']

Current_Year         = start_current_month.strftime("%Y")

Columns_to_Remove    = [['location','time','lat','long'],['location','time','lat','long'],['location','time','sdi12_version','sdi12_vendor_id','sdi12_sensor_model','sdi12_sensor_version','sdi12_sensor_sn'],['location','time','lat','long']]
Data_Type            = ["Daily", "Hourly", "Soil", "Calibrated"]
Data_Types           = ["daily", "hourly", "aux_raw", "calibrated"]

Column_Names         = [Daily_Data_Columns, Hourly_Data_Columns, Soil_Data_Columns, Calibrated_Data_Columns]

# %%
for i in range(len(Sensor_ID)):
    for g in range(len(m_start[i])):       
        Sensor = Sensor_ID[i]
        Habi   = Habitat[i]
        print(Habi)
        Start = m_start[i][g]
        End   = ymd_hms_to_dt(m_end[i][g])
        print(Start)
        print(End)
        Folder_Name_A = str(dirpath + Site[i] + '/' + Habitat[i] + '/' + str(ymd_hms_to_dt(Start).strftime("%Y")) + '/')
        for j in range(len(Data_Type)):
            Folder_Name = str(Folder_Name_A + Data_Type[j] + '/')
            if not os.path.exists(Folder_Name):
                os.makedirs(Folder_Name)
                print "Directory " , Folder_Name ,  " Created "
            else:    
                print "Directory " , Folder_Name ,  " already exists"  
                pass
            write_csv_file(Start, End, Data_Types[j], Data_Type[j], Folder_Name, dt_to_ym(ymd_hms_to_dt(Start)), Column_Names[j], Columns_to_Remove[j], Sensor, Habi, Site[i])
# Out:
# Annual_Grass
# 2019-02-05 00:00:00
# 2019-03-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-02_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-02_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-02_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-02_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-02_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-02_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-02_Calibrated.csv
# Annual_Grass
# 2019-03-01T00:00:00Z
# 2019-04-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-03_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-03_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-03_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-03_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-03_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-03_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-03_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-03_Calibrated.csv
# Annual_Grass
# 2019-04-01T00:00:00Z
# 2019-05-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-04_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-04_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-04_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-04_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-04_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-04_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-04_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-04_Calibrated.csv
# Annual_Grass
# 2019-05-01T00:00:00Z
# 2019-06-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-05_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-05_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-05_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-05_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-05_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-05_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-05_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-05_Calibrated.csv
# Annual_Grass
# 2019-06-01T00:00:00Z
# 2019-07-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-06_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-06_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-06_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-06_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-06_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-06_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-06_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-06_Calibrated.csv
# Annual_Grass
# 2019-07-01T00:00:00Z
# 2019-08-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-07_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-07_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-07_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-07_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-07_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-07_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-07_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-07_Calibrated.csv
# Annual_Grass
# 2019-08-01T00:00:00Z
# 2019-09-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-08_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-08_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-08_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-08_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-08_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-08_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-08_Calibrated.csv
# Annual_Grass
# 2019-09-01T00:00:00Z
# 2019-10-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-09_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-09_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-09_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-09_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-09_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-09_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-09_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-09_Calibrated.csv
# Annual_Grass
# 2019-10-01T00:00:00Z
# 2019-11-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-10_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-10_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-10_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-10_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-10_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-10_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-10_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-10_Calibrated.csv
# Annual_Grass
# 2019-11-01T00:00:00Z
# 2019-12-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-11_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-11_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-11_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-11_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-11_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-11_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-11_Calibrated.csv
# Annual_Grass
# 2019-12-01T00:00:00Z
# 2020-01-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Daily/Annual_Grass_2019-12_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Hourly/Annual_Grass_2019-12_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Soil/Annual_Grass_2019-12_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2019/Calibrated/Annual_Grass_2019-12_Calibrated.csv
# Annual_Grass
# 2020-01-01T00:00:00Z
# 2020-02-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Daily/Annual_Grass_2020-01_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Hourly/Annual_Grass_2020-01_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Soil/Annual_Grass_2020-01_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Calibrated/Annual_Grass_2020-01_Calibrated.csv
# Annual_Grass
# 2020-02-01T00:00:00Z
# 2020-03-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Daily/Annual_Grass_2020-02_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Hourly/Annual_Grass_2020-02_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Soil/Annual_Grass_2020-02_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Calibrated/Annual_Grass_2020-02_Calibrated.csv
# Annual_Grass
# 2020-03-01T00:00:00Z
# 2020-04-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Daily/Annual_Grass_2020-03_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Daily/Annual_Grass_2020-03_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Hourly/Annual_Grass_2020-03_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Hourly/Annual_Grass_2020-03_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Soil/Annual_Grass_2020-03_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Calibrated/Annual_Grass_2020-03_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Calibrated/Annual_Grass_2020-03_Calibrated.csv
# Annual_Grass
# 2020-04-01T00:00:00Z
# 2020-04-08 17:26:15
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Daily/Annual_Grass_2020-04_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Daily/Annual_Grass_2020-04_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Hourly/Annual_Grass_2020-04_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Hourly/Annual_Grass_2020-04_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Soil/Annual_Grass_2020-04_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Calibrated/Annual_Grass_2020-04_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Annual_Grass/2020/Calibrated/Annual_Grass_2020-04_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-02-05 00:00:00
# 2019-03-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  Created
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-02_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-02_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  Created
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-02_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-02_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  Created
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-02_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  Created
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-02_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-02_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-03-01T00:00:00Z
# 2019-04-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-03_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-03_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-03_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-03_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-03_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-03_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-03_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-03_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-04-01T00:00:00Z
# 2019-05-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-04_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-04_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-04_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-04_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-04_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-04_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-04_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-04_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-05-01T00:00:00Z
# 2019-06-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-05_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-05_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-05_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-05_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-05_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-05_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-05_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-05_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-06-01T00:00:00Z
# 2019-07-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-06_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-06_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-06_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-06_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-06_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-06_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-06_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-06_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-07-01T00:00:00Z
# 2019-08-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-07_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-07_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-07_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-07_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-07_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-07_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-07_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-08-01T00:00:00Z
# 2019-09-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-08_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-08_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-08_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-08_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-08_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-08_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-08_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-08_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-09-01T00:00:00Z
# 2019-10-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-09_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-09_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-09_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-09_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-09_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-09_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-09_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-09_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-10-01T00:00:00Z
# 2019-11-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-10_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-10_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-10_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-10_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-10_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-10_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-10_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-10_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-11-01T00:00:00Z
# 2019-12-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-11_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-11_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-11_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-11_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-11_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-11_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-11_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-11_Calibrated.csv
# Coastal_Sage_Scrub
# 2019-12-01T00:00:00Z
# 2020-01-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-12_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Daily/Coastal_Sage_Scrub_2019-12_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-12_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Hourly/Coastal_Sage_Scrub_2019-12_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-12_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Soil/Coastal_Sage_Scrub_2019-12_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-12_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2019/Calibrated/Coastal_Sage_Scrub_2019-12_Calibrated.csv
# Coastal_Sage_Scrub
# 2020-01-01T00:00:00Z
# 2020-02-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/Coastal_Sage_Scrub_2020-01_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/Coastal_Sage_Scrub_2020-01_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/Coastal_Sage_Scrub_2020-01_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/Coastal_Sage_Scrub_2020-01_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/Coastal_Sage_Scrub_2020-01_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/Coastal_Sage_Scrub_2020-01_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/Coastal_Sage_Scrub_2020-01_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/Coastal_Sage_Scrub_2020-01_Calibrated.csv
# Coastal_Sage_Scrub
# 2020-02-01T00:00:00Z
# 2020-03-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/Coastal_Sage_Scrub_2020-02_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/Coastal_Sage_Scrub_2020-02_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/Coastal_Sage_Scrub_2020-02_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/Coastal_Sage_Scrub_2020-02_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/Coastal_Sage_Scrub_2020-02_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/Coastal_Sage_Scrub_2020-02_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/Coastal_Sage_Scrub_2020-02_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/Coastal_Sage_Scrub_2020-02_Calibrated.csv
# Coastal_Sage_Scrub
# 2020-03-01T00:00:00Z
# 2020-04-01 00:00:00
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/Coastal_Sage_Scrub_2020-03_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/Coastal_Sage_Scrub_2020-03_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/Coastal_Sage_Scrub_2020-03_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/Coastal_Sage_Scrub_2020-03_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/Coastal_Sage_Scrub_2020-03_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/Coastal_Sage_Scrub_2020-03_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/Coastal_Sage_Scrub_2020-03_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/Coastal_Sage_Scrub_2020-03_Calibrated.csv
# Coastal_Sage_Scrub
# 2020-04-01T00:00:00Z
# 2020-04-08 17:26:15
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/Coastal_Sage_Scrub_2020-04_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Daily/Coastal_Sage_Scrub_2020-04_Daily.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/Coastal_Sage_Scrub_2020-04_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Hourly/Coastal_Sage_Scrub_2020-04_Hourly.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/Coastal_Sage_Scrub_2020-04_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Soil/Coastal_Sage_Scrub_2020-04_Soil.csv
# Directory  C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/  already exists
# C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/Coastal_Sage_Scrub_2020-04_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/Campus_Lagoon/Coastal_Sage_Scrub/2020/Calibrated/Coastal_Sage_Scrub_2020-04_Calibrated.csv
# Ventura_Marsh_Milk-Vetch
# 2019-03-18 00:00:00
# 2019-04-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Daily/  Created
# C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Daily/Ventura_Marsh_Milk-Vetch_2019-03_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Daily/Ventura_Marsh_Milk-Vetch_2019-03_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Hourly/  Created
# C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Hourly/Ventura_Marsh_Milk-Vetch_2019-03_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Hourly/Ventura_Marsh_Milk-Vetch_2019-03_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Soil/  Created
# C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Soil/Ventura_Marsh_Milk-Vetch_2019-03_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Calibrated/  Created
# C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Calibrated/Ventura_Marsh_Milk-Vetch_2019-03_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Calibrated/Ventura_Marsh_Milk-Vetch_2019-03_Calibrated.csv
# Ventura_Marsh_Milk-Vetch
# 2019-04-01T00:00:00Z
# 2019-05-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Daily/Ventura_Marsh_Milk-Vetch_2019-04_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Daily/Ventura_Marsh_Milk-Vetch_2019-04_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Hourly/Ventura_Marsh_Milk-Vetch_2019-04_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Hourly/Ventura_Marsh_Milk-Vetch_2019-04_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Ventura_Marsh_Milk-Vetch/2019/Soil/Ventura_Marsh_Milk-Vetch_2019-04_Soil.csv
# ...
# Stipa_Loam
# 2019-07-01T00:00:00Z
# 2019-08-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-07_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-07_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-07_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-07_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/Stipa_Loam_2019-07_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-07_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-07_Calibrated.csv
# Stipa_Loam
# 2019-08-01T00:00:00Z
# 2019-09-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-08_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-08_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-08_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-08_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/Stipa_Loam_2019-08_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-08_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-08_Calibrated.csv
# Stipa_Loam
# 2019-09-01T00:00:00Z
# 2019-10-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-09_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-09_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-09_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-09_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/Stipa_Loam_2019-09_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/Stipa_Loam_2019-09_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-09_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-09_Calibrated.csv
# Stipa_Loam
# 2019-10-01T00:00:00Z
# 2019-11-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-10_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-10_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-10_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-10_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/Stipa_Loam_2019-10_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/Stipa_Loam_2019-10_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-10_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-10_Calibrated.csv
# Stipa_Loam
# 2019-11-01T00:00:00Z
# 2019-12-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-11_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-11_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-11_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-11_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/Stipa_Loam_2019-11_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/Stipa_Loam_2019-11_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-11_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-11_Calibrated.csv
# Stipa_Loam
# 2019-12-01T00:00:00Z
# 2020-01-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-12_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Daily/Stipa_Loam_2019-12_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-12_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Hourly/Stipa_Loam_2019-12_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/Stipa_Loam_2019-12_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Soil/Stipa_Loam_2019-12_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-12_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2019/Calibrated/Stipa_Loam_2019-12_Calibrated.csv
# Stipa_Loam
# 2020-01-01T00:00:00Z
# 2020-02-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/Stipa_Loam_2020-01_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/Stipa_Loam_2020-01_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/Stipa_Loam_2020-01_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/Stipa_Loam_2020-01_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/Stipa_Loam_2020-01_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/Stipa_Loam_2020-01_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/Stipa_Loam_2020-01_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/Stipa_Loam_2020-01_Calibrated.csv
# Stipa_Loam
# 2020-02-01T00:00:00Z
# 2020-03-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/Stipa_Loam_2020-02_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/Stipa_Loam_2020-02_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/Stipa_Loam_2020-02_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/Stipa_Loam_2020-02_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/Stipa_Loam_2020-02_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/Stipa_Loam_2020-02_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/Stipa_Loam_2020-02_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/Stipa_Loam_2020-02_Calibrated.csv
# Stipa_Loam
# 2020-03-01T00:00:00Z
# 2020-04-01 00:00:00
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/Stipa_Loam_2020-03_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/Stipa_Loam_2020-03_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/Stipa_Loam_2020-03_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/Stipa_Loam_2020-03_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/Stipa_Loam_2020-03_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/Stipa_Loam_2020-03_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/Stipa_Loam_2020-03_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/Stipa_Loam_2020-03_Calibrated.csv
# Stipa_Loam
# 2020-04-01T00:00:00Z
# 2020-04-08 17:26:15
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/Stipa_Loam_2020-04_Daily.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Daily/Stipa_Loam_2020-04_Daily.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/Stipa_Loam_2020-04_Hourly.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Hourly/Stipa_Loam_2020-04_Hourly.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/Stipa_Loam_2020-04_Soil.csv
# Remove location
# Remove time
# Remove sdi12_version
# Remove sdi12_vendor_id
# Remove sdi12_sensor_model
# Remove sdi12_sensor_version
# Remove sdi12_sensor_sn
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Soil/Stipa_Loam_2020-04_Soil.csv
# Directory  C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/  already exists
# C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/Stipa_Loam_2020-04_Calibrated.csv
# Remove location
# Remove time
# Remove lat
# Remove long
# Successfully wrote C:/Users/15303/Documents/North_Campus_Open_Space/Stipa_Loam/2020/Calibrated/Stipa_Loam_2020-04_Calibrated.csv
